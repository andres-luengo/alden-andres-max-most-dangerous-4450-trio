# %%
import numpy as np
import pandas as pd

# %%
import os

# %% [markdown]
# # Clean the data

# %%
gen = pd.read_csv("data/TEK00082.CSV", skiprows=15)
gen
# Out:
#            TIME   CH1
# 0     -0.088400  0.50
# 1     -0.088392  0.75
# 2     -0.088384  0.75
# 3     -0.088376  0.75
# 4     -0.088368  0.50
# ...         ...   ...
# 19995  0.071560  8.00
# 19996  0.071568  8.00
# 19997  0.071576  8.00
# 19998  0.071584  8.00
# 19999  0.071592  8.00
#
# [20000 rows x 2 columns]

# %%
gen.plot.scatter(x="TIME", y="CH1", s=1)
# Out:
# <Axes: xlabel='TIME', ylabel='CH1'>

# %%
fp = pd.read_csv("data/TEK00083.CSV", skiprows=15)
fp
# Out:
#            TIME     CH2
# 0     -0.088400  0.0275
# 1     -0.088392  0.0325
# 2     -0.088384  0.0350
# 3     -0.088376  0.0400
# 4     -0.088368  0.0350
# ...         ...     ...
# 19995  0.071560  0.2350
# 19996  0.071568  0.2300
# 19997  0.071576  0.2125
# 19998  0.071584  0.2100
# 19999  0.071592  0.1775
#
# [20000 rows x 2 columns]

# %%
fp.plot(x="TIME", y="CH2")
# Out:
# <Axes: xlabel='TIME'>

# %%
sat = pd.read_csv("data/TEK00084.CSV", skiprows=15)
sat
# Out:
#            TIME   CH4
# 0     -0.088400  48.0
# 1     -0.088392  48.0
# 2     -0.088384  48.0
# 3     -0.088376  48.0
# 4     -0.088368  48.0
# ...         ...   ...
# 19995  0.071560  95.0
# 19996  0.071568  95.5
# 19997  0.071576  95.0
# 19998  0.071584  95.0
# 19999  0.071592  95.0
#
# [20000 rows x 2 columns]

# %%
sat.plot(x="TIME", y="CH4")
# Out:
# <Axes: xlabel='TIME'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(gen["CH1"], sat["CH4"], s=4)
# plt.plot(gen["CH1"], sat["CH4"])
plt.xlabel("Function Generator Voltage (V)")
plt.ylabel("Absorption Signal Voltage (V?)")
# Out:
# Text(0, 0.5, 'Absorption Signal Voltage (V?)')

# %%
saturated_data = {
    "GEN": gen,
    "FP": fp,
    "SIG": sat
}

# %%
gen = pd.read_csv("data/TEK00069.CSV", skiprows=15)
gen
# Out:
#          TIME   CH1
# 0    -0.09040   1.4
# 1    -0.09032   1.4
# 2    -0.09024   1.4
# 3    -0.09016   1.4
# 4    -0.09008   1.4
# ...       ...   ...
# 1995  0.06920  10.8
# 1996  0.06928  10.8
# 1997  0.06936  10.8
# 1998  0.06944  10.8
# 1999  0.06952  10.8
#
# [2000 rows x 2 columns]

# %%
gen.plot(x="TIME", y="CH1")
# Out:
# <Axes: xlabel='TIME'>

# %%
fp = pd.read_csv("data/TEK00070.CSV", skiprows=15)
fp
# Out:
#          TIME    CH2
# 0    -0.09040  0.005
# 1    -0.09032  0.010
# 2    -0.09024  0.015
# 3    -0.09016  0.005
# 4    -0.09008  0.015
# ...       ...    ...
# 1995  0.06920  0.010
# 1996  0.06928  0.015
# 1997  0.06936  0.010
# 1998  0.06944  0.005
# 1999  0.06952  0.020
#
# [2000 rows x 2 columns]

# %%
fp.plot(x="TIME", y="CH2")
# Out:
# <Axes: xlabel='TIME'>

# %%
sat = pd.read_csv("data/TEK00071.CSV", skiprows=15)
sat
# Out:
#          TIME   CH4
# 0    -0.09040  70.5
# 1    -0.09032  70.5
# 2    -0.09024  70.5
# 3    -0.09016  70.5
# 4    -0.09008  70.5
# ...       ...   ...
# 1995  0.06920  68.5
# 1996  0.06928  69.0
# 1997  0.06936  69.5
# 1998  0.06944  69.0
# 1999  0.06952  69.5
#
# [2000 rows x 2 columns]

# %%
sat.plot(x="TIME", y="CH4")
# Out:
# <Axes: xlabel='TIME'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(gen["CH1"], sat["CH4"], s=4)
# plt.plot(gen["CH1"], sat["CH4"])
plt.xlabel("Function Generator Voltage (V)")
plt.ylabel("Absorption Signal Voltage (V?)")
# Out:
# Text(0, 0.5, 'Absorption Signal Voltage (V?)')

# %%
saturated_data = {
    "GEN": gen,
    "FP": fp,
    "SIG": sat
}
