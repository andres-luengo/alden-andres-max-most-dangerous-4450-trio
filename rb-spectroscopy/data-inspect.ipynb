# %%
import numpy as np
import pandas as pd

# %%
import os

# %% [markdown]
# # Clean the data

# %%
gen = pd.read_csv("data/saturated/no_magnet/signal_gen.CSV", skiprows=15)
gen
# Out:
#            TIME   CH1
# 0     -0.068800  18.0
# 1     -0.068792  18.0
# 2     -0.068784  18.0
# 3     -0.068776  18.0
# 4     -0.068768  18.0
# ...         ...   ...
# 19995  0.091160  50.0
# 19996  0.091168  49.5
# 19997  0.091176  50.0
# 19998  0.091184  50.0
# 19999  0.091192  50.0
#
# [20000 rows x 2 columns]

# %%
gen.plot.scatter(x="TIME", y="CH1", s=1)
# Out:
# <Axes: xlabel='TIME', ylabel='CH1'>

# %%
fp = pd.read_csv("data/saturated/no_magnet/fabry_perot.CSV", skiprows=15)
fp
# Out:
#            TIME           CH2
# 0     -0.068800  1.000000e-02
# 1     -0.068792  4.768370e-09
# 2     -0.068784  2.000000e-02
# 3     -0.068776  4.768370e-09
# 4     -0.068768  1.000000e-02
# ...         ...           ...
# 19995  0.091160  1.000000e-02
# 19996  0.091168  4.768370e-09
# 19997  0.091176  2.000000e-02
# 19998  0.091184  2.000000e-02
# 19999  0.091192  2.000000e-02
#
# [20000 rows x 2 columns]

# %%
fp.plot(x="TIME", y="CH2")
# Out:
# <Axes: xlabel='TIME'>

# %%
sat = pd.read_csv("data/saturated/no_magnet/data.CSV", skiprows=15)
sat
# Out:
#            TIME   CH4
# 0     -0.068800  78.0
# 1     -0.068792  78.5
# 2     -0.068784  78.5
# 3     -0.068776  77.5
# 4     -0.068768  78.0
# ...         ...   ...
# 19995  0.091160  73.5
# 19996  0.091168  73.5
# 19997  0.091176  73.5
# 19998  0.091184  74.0
# 19999  0.091192  73.5
#
# [20000 rows x 2 columns]

# %%
sat.plot(x="TIME", y="CH4")
# Out:
# <Axes: xlabel='TIME'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hexbin(gen["CH1"], sat["CH4"])
# plt.plot(gen["CH1"], sat["CH4"])
plt.xlabel("Function Generator Voltage (V)")
plt.ylabel("Absorption Signal Voltage (V?)")
# Out:
# Text(0, 0.5, 'Absorption Signal Voltage (V?)')

# %%
saturated_data = {
    "GEN": gen,
    "FP": fp,
    "SIG": sat
}

# %%
gen = pd.read_csv("data/TEK00069.CSV", skiprows=15)
gen
# Out:
#          TIME   CH1
# 0    -0.09040   1.4
# 1    -0.09032   1.4
# 2    -0.09024   1.4
# 3    -0.09016   1.4
# 4    -0.09008   1.4
# ...       ...   ...
# 1995  0.06920  10.8
# 1996  0.06928  10.8
# 1997  0.06936  10.8
# 1998  0.06944  10.8
# 1999  0.06952  10.8
#
# [2000 rows x 2 columns]

# %%
gen.plot(x="TIME", y="CH1")
# Out:
# <Axes: xlabel='TIME'>

# %%
fp = pd.read_csv("data/TEK00070.CSV", skiprows=15)
fp
# Out:
#          TIME    CH2
# 0    -0.09040  0.005
# 1    -0.09032  0.010
# 2    -0.09024  0.015
# 3    -0.09016  0.005
# 4    -0.09008  0.015
# ...       ...    ...
# 1995  0.06920  0.010
# 1996  0.06928  0.015
# 1997  0.06936  0.010
# 1998  0.06944  0.005
# 1999  0.06952  0.020
#
# [2000 rows x 2 columns]

# %%
fp.plot(x="TIME", y="CH2")
# Out:
# <Axes: xlabel='TIME'>

# %%
sat = pd.read_csv("data/TEK00071.CSV", skiprows=15)
sat
# Out:
#          TIME   CH4
# 0    -0.09040  70.5
# 1    -0.09032  70.5
# 2    -0.09024  70.5
# 3    -0.09016  70.5
# 4    -0.09008  70.5
# ...       ...   ...
# 1995  0.06920  68.5
# 1996  0.06928  69.0
# 1997  0.06936  69.5
# 1998  0.06944  69.0
# 1999  0.06952  69.5
#
# [2000 rows x 2 columns]

# %%
sat.plot(x="TIME", y="CH4")
# Out:
# <Axes: xlabel='TIME'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(gen["CH1"], sat["CH4"], s=4)
# plt.plot(gen["CH1"], sat["CH4"])
plt.xlabel("Function Generator Voltage (V)")
plt.ylabel("Absorption Signal Voltage (V?)")
# Out:
# Text(0, 0.5, 'Absorption Signal Voltage (V?)')

# %%
saturated_data = {
    "GEN": gen,
    "FP": fp,
    "SIG": sat
}

# %%
# Out:
# ✅ All TIME columns are identical across 3 CSV files in data/saturated/magnet.
